# %% [markdown]
# Label:- Task1

# %%
#importing the libraries which is used for EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import  seaborn as sns
# %matplotlib inline

# %%
#importing the warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#importing dataset
df=pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\internship data\\dataset.csv")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
#checking for missing values in each column and handle them accordingly

df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# #there are only 9 missing values in "cuisines" which is very less.
#
# #so, we can ignore or just replace these with "not specified.

# %%
df['Cuisines'].fillna('not specified',inplace=True)

# %%
#checking once again
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#checking duplicates
dup=df.duplicated().sum()
print(f'Number of Duplicated Rows are(dup)')
# Out:
# Number of Duplicated Rows are(dup)

# %% [markdown]
# #permorming data type conversion if it is necessary and analyse the distribution of the target variable ("aggregate rating")and identify any class imbalance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# there is no any need for data type conversion

# %%
#target variable "Aggregate rating"
target="Aggregate rating"
#Descriptive Statistics
print(df[target].describe())
# Out:
# count    9551.000000
# mean        2.666370
# std         1.516378
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
#Box Plot
plt.figure(figsize=(9,4))
sns.boxplot(x=df[target])
plt.title('Box Plot')
plt.xlabel('Aggregate rating')
plt.show()

# %%
#Histogram
plt.figure(figsize=(7,4))
sns.histplot(df[target],bins=30,kde=True,color='skyblue')
plt.title('Histogram')
plt.xlabel('Aggregate rating')
plt.ylabel('Freuency')
plt.show()

# %% [markdown]
# No class imbalance

# %% [markdown]
# Label1:- Task2

# %% [markdown]
# Descriptive Analysis

# %%
#Calculate basic stastical measure(mean,median,standard deviation,etc.)for numerical columns
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df[["Average Cost for two","Price range","Aggregate rating","Votes"]].describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [markdown]
# Exploring the distribution of catogrical variable like "country code","city",and "cuisines". Identify the top cuisines and cities with the highest number of resturents.

# %%
#explore the distribution of "country code"
plt.figure(figsize=(8,5))
sns.countplot(x='Country Code',data=df,palette='cividis')
plt.title('Distribution of Resturents by country code')
plt.xlabel=('Country Code')
plt.ylabel=('Number of Resturents')
plt.show()

# %% [markdown]
# Majority of the resturant are located in country code 1. followed by the second highest concentration in country code 216.

# %%
#top countries with the highest number of resturants.
top_countries=df["Country Code"].value_counts().head()
print('Top 5 Countries with the Highest Number of Resturents:')
print(top_countries)
# Out:
# Top 5 Countries with the Highest Number of Resturents:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# Name: count, dtype: int64

# %%
#Explore the distribution of ""city"
plt.figure(figsize=(19,7))

sns.countplot(x='City', data=df, order=df['City'].value_counts().head(20).index, palette='Set2') 
      
plt.title('Distribution of Restaurants by City')
plt.xlabel('City')
plt.ylabel('Number of Restaurents')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 7
#       4 sns.countplot(x='City', data=df, order=df['City'].value_counts().head(20).index, palette='Set2')
#       6 plt.title('Distribution of Restaurants by City')
# ----> 7 plt.xlabel('City')
#       8 plt.ylabel('Number of Restaurents')
#       9 plt.xticks(rotation=45)
#
# TypeError: 'str' object is not callable

# %%
#explore the distribution of "cuisines"
plt.figure(figsize=(15,6))
cuisines_count= df['Cuisines'].value_counts()
cuisines_count.head(20).plot(kind='bar',color=sns.color_palette("Set2"))
plt.title('top20 cuisines with the highest number of restaurants')
plt.xlabel('Cuisines')
plt.ylabel('number of restaurents')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 6
#       4 cuisines_count.head(20).plot(kind='bar',color=sns.color_palette("Set2"))
#       5 plt.title('top20 cuisines with the highest number of restaurants')
# ----> 6 plt.xlabel('Cuisines')
#       7 plt.ylabel('number of restaurents')
#       8 plt.xticks(rotation=45)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Top Cuisines and Cities

# %%
#Top Cities with the highest number of restaurants 
top_cities= df['City'].value_counts().head(10)
print('Top 10 cities with hughest number of restaurants:')
print(top_cities)
# Out:
# Top 10 cities with hughest number of restruents:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %%
#Top Cuisines with the highest number of restaurants
top_cuisines= cuisines_count.head(10)
print('Top 10 cities with highest number of restaurants')
print(top_cuisines)
# Out:
# Top 10 cities with highest number of restaurants
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %% [markdown]
# Label1 task3
#
# Geospatical Analysis
#
# 1. visualise the location of restaurants on a map using latitude and longitude information.

# %%
#Location of restaurants on a map using latitude and longitude information 
#import the necessary libraries

from shapely.geometry import point 
import geopandas as gpd
from geopandas import GeoDataFrame

# %%
#create point geometry from latitude and longitude using shapely 
gdf=gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

#create a base map of the world using Geopandas
world=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

#create a map that fit the screen and plots the restaurant locations
gdf.plot (ax=world.plot("continent",legend=True, figsize=(18,15)),marker='o',color='red',markersize=15)
plt.show()

# %% [markdown]
# #Analyse the distribution of restaurants across diffrent cities or countries. Determine if there is any corelation between the restaurents location and its rating.

# %%
#Distribution of restaurants across diffrent cities or countries 

plt.figure(figsize=(8,5))

#there are many cities names present in the data , so i select only the top 10 cities

sns.countplot(y=df['City'], order=df.City.value_counts().head(10).index, palette='Set2')
plt.xlabel('Number of Rasturants ')
plt.ylabel('Number of Cities')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 8
#       5 #there are many cities names present in the data , so i select only the top 10 cities
#       7 sns.countplot(y=df['City'], order=df.City.value_counts().head(10).index, palette='Set2')
# ----> 8 plt.xlabel('Number of Rasturants ')
#       9 plt.ylabel('Number of Cities')
#      10 plt.show()
#
# TypeError: 'str' object is not callable

# %%
#checking corelation between the restauranat's location and its rating 
plt.figure(figsize=(8, 6))

#calculate the corelation between latitude, longitude, and rating
correlation_matrix=df[['Latitude','Longitude','Aggregate rating']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("correlation between Restaurant's location and rating")
plt.show()

# %% [markdown]
# Saving the dataset to the next label task

# %%
#specify the desired file path and name for the next csv file  
output_file_path=("C:\\Users\\DELL\\OneDrive\\Desktop\\internship data\\dataset.csv")

#save the DataFrame to the new csv file
df.to_csv(output_file_path, index=False)

print(f"DataFrame has been successfully saved to(output_file_path)")
# Out:
# DataFrame has been successfully saved to(output_file_path)
